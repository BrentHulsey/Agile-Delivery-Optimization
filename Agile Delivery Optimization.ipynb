# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

p = 5
d = 4
k = 3
h = 2
x = np.linspace(0,20) # 100 linearly spaced numbers
y =  p*d+k*d/x + h*x #EOQ model

# compose plot
plt.plot(x,y) # sin(x)/x
# Out:
# C:\Users\brent.hulsey\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
